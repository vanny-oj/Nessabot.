# %% [markdown]
# <a href="https://colab.research.google.com/github/vanny-oj/Nessabot./blob/main/Copy_of_Patience_NessaBot_Chatterbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from chatterbot import ChatBot
from chatterbot.trainers import ChatterBotCorpusTrainer

# %%
# !pip install chatterbot
# !pip install chatterbot_corpus
from chatterbot import ChatBot
from chatterbot.trainers import ChatterBotCorpusTrainer

# %%
chatbot = ChatBot('NessaBot')

# %%
trainer = ChatterBotCorpusTrainer(chatbot)

# %%
trainer.train('chatterbot.corpus.english')
# Out:
# Training corpus: 21it [00:05,  3.64it/s]

# %%
ChatBot = ChatBot('God t')
print(" Hello! I am NessaBot.")

print("Ask me how to know about God. Type 'bye' to exit.\n")
# Out:
#  Hello! I am NessaBot.
# Ask me how to know about God. Type 'bye' to exit.

# %%
#dictionary
responses = {
    "Who is God?": "God is your Creator and the creator of the universe.",

    "how do i know God": " You know God by going to church, reading and studying scriptures, praying and Fasting.",

    "how long do i need to pray": "You pray daily for 30mins and more.",

    "Where is God? ": "He is everywhere, Omnipresent."
}

# %%
while True:
    user_input = input("You: ").lower()

    if user_input == "bye":
        print("NessaBot: Goodbye! Go and pray")
        break

    response = responses.get(user_input,
        "NessaBot: God is your Creator and the creator of the universe.")

    print("NessaBot:", response)
# Out:
# You: Who is God
# NessaBot: NessaBot: God is your Creator and the creator of the universe.
# You: Bye
# NessaBot: Goodbye! Go and pray
